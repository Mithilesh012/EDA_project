# %% [markdown]
# <pre>Steps for EDA:
#        1 Loading Data
#        2 Understanding Data Structure
#        3 Missing Data Analysis
#        4 Summary Statistics
#        5 Visualizing Relationships between Features
#        6 Outlier Detection
#        7 Correlation Analysis</pre>

# %% [markdown]
# <h1>1 Loading Data</h1>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns


df = pd.read_csv('AmesHousing.csv')

# %% [markdown]
# <h1>2 Understanding Data Structure</h1>

# %%
df.head()
# Out:
#    Order        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 0      1  526301100           20        RL         141.0     31770   Pave
# 1      2  526350040           20        RH          80.0     11622   Pave
# 2      3  526351010           20        RL          81.0     14267   Pave
# 3      4  526353030           20        RL          93.0     11160   Pave
# 4      5  527105010           60        RL          74.0     13830   Pave
#
#   Alley Lot Shape Land Contour  ... Pool Area Pool QC  Fence Misc Feature  \
# 0   NaN       IR1          Lvl  ...         0     NaN    NaN          NaN
# 1   NaN       Reg          Lvl  ...         0     NaN  MnPrv          NaN
# 2   NaN       IR1          Lvl  ...         0     NaN    NaN         Gar2
# 3   NaN       Reg          Lvl  ...         0     NaN    NaN          NaN
# 4   NaN       IR1          Lvl  ...         0     NaN  MnPrv          NaN
#
#   Misc Val Mo Sold Yr Sold Sale Type  Sale Condition  SalePrice
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2930 entries, 0 to 2929
# Data columns (total 82 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Order            2930 non-null   int64
#  1   PID              2930 non-null   int64
#  2   MS SubClass      2930 non-null   int64
#  3   MS Zoning        2930 non-null   object
#  4   Lot Frontage     2440 non-null   float64
#  5   Lot Area         2930 non-null   int64
#  6   Street           2930 non-null   object
#  7   Alley            198 non-null    object
#  8   Lot Shape        2930 non-null   object
#  9   Land Contour     2930 non-null   object
#  10  Utilities        2930 non-null   object
#  11  Lot Config       2930 non-null   object
#  12  Land Slope       2930 non-null   object
#  13  Neighborhood     2930 non-null   object
#  14  Condition 1      2930 non-null   object
#  15  Condition 2      2930 non-null   object
# ...

# %%
df.shape
# Out:
# (2930, 82)

# %%
df.describe()
# Out:
#             Order           PID  MS SubClass  Lot Frontage       Lot Area  \
# count  2930.00000  2.930000e+03  2930.000000   2440.000000    2930.000000
# mean   1465.50000  7.144645e+08    57.387372     69.224590   10147.921843
# std     845.96247  1.887308e+08    42.638025     23.365335    7880.017759
# min       1.00000  5.263011e+08    20.000000     21.000000    1300.000000
# 25%     733.25000  5.284770e+08    20.000000     58.000000    7440.250000
# 50%    1465.50000  5.354536e+08    50.000000     68.000000    9436.500000
# 75%    2197.75000  9.071811e+08    70.000000     80.000000   11555.250000
# max    2930.00000  1.007100e+09   190.000000    313.000000  215245.000000
#
#        Overall Qual  Overall Cond   Year Built  Year Remod/Add  Mas Vnr Area  \
# count   2930.000000   2930.000000  2930.000000     2930.000000   2907.000000
# mean       6.094881      5.563140  1971.356314     1984.266553    101.896801
# ...

# %% [markdown]
# <h1>3 Missing Data Analysis</h1>

# %%
df.isnull().sum()
# Out:
# Order               0
# PID                 0
# MS SubClass         0
# MS Zoning           0
# Lot Frontage      490
#                  ...
# Mo Sold             0
# Yr Sold             0
# Sale Type           0
# Sale Condition      0
# SalePrice           0
# Length: 82, dtype: int64

# %%
missing_data = df.isnull().sum().sort_values(ascending=False)
missing_data = missing_data[missing_data > 0]  # Filter out columns without missing data

missing_data
# Out:
# Pool QC           2917
# Misc Feature      2824
# Alley             2732
# Fence             2358
# Mas Vnr Type      1775
# Fireplace Qu      1422
# Lot Frontage       490
# Garage Cond        159
# Garage Finish      159
# Garage Yr Blt      159
# Garage Qual        159
# Garage Type        157
# Bsmt Exposure       83
# BsmtFin Type 2      81
# Bsmt Qual           80
# Bsmt Cond           80
# BsmtFin Type 1      80
# Mas Vnr Area        23
# Bsmt Full Bath       2
# Bsmt Half Bath       2
# BsmtFin SF 1         1
# Garage Cars          1
# Electrical           1
# Total Bsmt SF        1
# Bsmt Unf SF          1
# BsmtFin SF 2         1
# Garage Area          1
# dtype: int64

# %%
# Analyzing 'Neighborhood'
plt.figure(figsize=(10,6))
sns.countplot(x='Neighborhood', data=data, order=data['Neighborhood'].value_counts().index)
plt.xticks(rotation=90)
plt.show()

# %%
#House Prices by Neighborhood or Location
# Grouping by neighborhood and calculating the mean sale price
neighborhood_prices = data.groupby('Neighborhood')['SalePrice'].mean()
print(neighborhood_prices.sort_values(ascending=False))
# Out:
# Neighborhood
# NoRidge    330319.126761
# StoneBr    324229.196078
# NridgHt    322018.265060
# GrnHill    280000.000000
# Veenker    248314.583333
# Timber     246599.541667
# Somerst    229707.324176
# ClearCr    208662.090909
# Crawfor    207550.834951
# CollgCr    201803.434457
# Blmngtn    196661.678571
# Greens     193531.250000
# Gilbert    190646.575758
# NWAmes     188406.908397
# SawyerW    184070.184000
# Mitchel    162226.631579
# NAmes      145097.349887
# Blueste    143590.000000
# NPkVill    140710.869565
# Landmrk    137000.000000
# Sawyer     136751.152318
# SWISU      135071.937500
# Edwards    130843.381443
# BrkSide    124756.250000
# OldTown    123991.891213
# BrDale     105608.333333
# IDOTRR     103752.903226
# MeadowV     95756.486486
# Name: SalePrice, dtype: float64

# %% [markdown]
# <h1>5. Visualizing Relationships between Features</h1>

# %%
# Visualizing the distribution of sale prices by neighborhood
plt.figure(figsize=(25, 20))
sns.boxplot(x='Neighborhood', y='SalePrice', data=data)
plt.title('Distribution of Sale Prices by Neighborhood')
plt.show()

# %%
sns.pairplot(df[['SalePrice', 'Gr Liv Area', 'Total Bsmt SF', 'Overall Qual']])
plt.show()

# %%
# Distribution of target variable (SalePrice)
sns.histplot(df['SalePrice'], kde=True)
plt.title('Distribution of House Prices')
plt.show()

# Distribution of a feature, e.g., GrLivArea (Above Ground Living Area)
sns.histplot(df['Gr Liv Area'], kde=True)
plt.title('Distribution of Above Ground Living Area')
plt.show()

# %%
# correlations = df.corr(numeric_only=True)['SalePrice'].sort_values(ascending=False)
 
# # Display the top 10 features most correlated with 'SalePrice'
# top_correlations = correlations[1:11]
# print(top_correlations)

# # Select the top correlated features including SalePrice
# selected_features = list(top_correlations.index) + ['SalePrice']

# # Compute the correlations for the selected features
# correlation_matrix = df[selected_features].corr()

# # Set up the matplotlib figure
# plt.figure(figsize=(12, 8))

# # Generate a heatmap
# sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm", linewidths=.5, fmt=".2f", vmin=-1, vmax=1)

# # Title
# plt.title("Heatmap of Correlations among Top Features with SalePrice", fontsize=16)

# # Show the heatmap
# plt.show()

# %% [markdown]
# <h1>6. Outlier Detection</h1>

# %%
# Scatter plot for identifying outliers in relation to GrLivArea and SalePrice
plt.figure(figsize=(10,6))
sns.scatterplot(x='Gr Liv Area', y='SalePrice', data=df)
plt.title('Sale Price vs. Living Area (GrLivArea)')
plt.show()

# Box plot for detecting outliers in OverallQual
sns.boxplot(x=df['Overall Qual'])
plt.title('Overall Quality Boxplot')
plt.show()

# %%
#Outliers in the Data
# Identifying outliers using the Z-score method
from scipy import stats

z_scores = np.abs(stats.zscore(data['SalePrice']))
print(data[z_scores > 3])

# Visualizing the distribution of sale prices
plt.figure(figsize=(10, 6))
sns.distplot(data['SalePrice'])
plt.title('Distribution of Sale Prices')
plt.show()
# Out:
#       Order        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 15       16  527216070           60        RL          47.0     53504   Pave
# 44       45  528150070           20        RL         100.0     12919   Pave
# 46       47  528176010           20        RL         110.0     14300   Pave
# 366     367  527214050           20        RL          63.0     17423   Pave
# 421     422  528102140           60        RL         110.0     14257   Pave
# 422     423  528104070           60        RL         104.0     13518   Pave
# 423     424  528106020           20        RL         105.0     15431   Pave
# 431     432  528110010           60        RL          97.0     13478   Pave
# 432     433  528110020           20        RL         105.0     13693   Pave
# 433     434  528110090           60        RL         107.0     13891   Pave
# 448     449  528166090           20        RL         110.0     15274   Pave
# ...

# %% [markdown]
# <h1>7. Correlation Analysis</h1> <p>wokrin on</p>
# Correlation analysis helps to identify the linear relationship between features. Create a correlation matrix and visualize it with a heatmap.

# %%
# from sklearn.preprocessing import LabelEncoder

# # Example of encoding a specific column
# df['SomeCategoricalColumn'] = LabelEncoder().fit_transform(df['SomeCategoricalColumn'])

# # Continue with the correlation analysis
# numeric_df = df.select_dtypes(include=['float64', 'int64'])
# corr_matrix = numeric_df.corr()

# plt.figure(figsize=(12,8))
# sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
# plt.title('Correlation Matrix with Label Encoded Features')
# plt.show()

# %%
# Correlation matrix
# corr_matrix = df.corr()

# # Heatmap of the correlation matrix
# plt.figure(figsize=(12,8))
# sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
# plt.title('Correlation Matrix of Features')
# plt.show()

# # Focused correlation with SalePrice
# corr_with_target = corr_matrix['SalePrice'].sort_values(ascending=False)
# print(corr_with_target.head(10))  # Top 10 correlated features with SalePrice

# %% [markdown]
# <h1>q and a</h1>

# %% [markdown]
# <h1><pre>
# -What are the most important features affecting house prices?
# - How do house prices vary by neighborhood or location?
# -Are there any outliers in the data, and what could be the reason for them?
# -
# What is the relationship between house size (square footage) and price</pre></h1>?

# %% [markdown]
# <pre>
#         House price prediction is a complex task that involves analyzing various features of a house and its surroundings to predict its price.
#
# The most important features affecting house prices include Overall Quality of the house, Living Area, Number of Full Baths, Size of Garage, and Year of Construction. These features have a significant impact on the price of a house.
#
# House prices vary significantly by neighborhood or location. For example, houses in neighborhoods with good schools, low crime rates, and easy access to amenities tend to be more expensive than those in neighborhoods with lower quality schools, higher crime rates, and limited access to amenitie        s.
#
# There are outliers in the data, which could be due to various reasons such as incorrect data entry, unusual house features, or houses that are significantly different from others in the neighborhood. For example, a house with a very large garage or a house with a unique architectural style could be an outl        ier.
#
# The relationship between house size (square footage) and price is generally positive, meaning that larger houses tend to be more expensive. However, this relationship can vary depending on the location and other features of th
# </pre>e house.

# %% [raw]
# Insights from EDA
# Important Features:
#
# Identify features with high correlation to the target (SalePrice) such as OverallQual, GrLivArea, etc.
# Visualize these relationships to see if the linearity assumptions hold.
# Price Variation by Neighborhood:
#
# The boxplot for Neighborhood vs. SalePrice shows how prices vary across different locations.
# Outliers:
#
# Scatter plots help detect extreme outliers which might need to be handled or excluded.
# Relationship Between Size and Price:
#
# Positive correlation between GrLivArea and SalePrice indicates that larger homes tend to have higher prices.
